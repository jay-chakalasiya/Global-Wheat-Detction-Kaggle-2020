# %%
from yolov5.yolov5.models.yolo import Model
import torch

# %%
M = Model(model_cfg='yolov5/yolov5/models/yolov5l.yaml', ch=3, nc=2)
#chkpt = torch.load('saved_weights/yolov5/yolov5x.pt')
# Out:
#               from  n    params  module                                  arguments
#   0             -1  1      7040  yolov5.yolov5.models.common.Focus       [3, 64, 3]
#   1             -1  1     73984  yolov5.yolov5.models.common.Conv        [64, 128, 3, 2]
#   2             -1  1    161152  yolov5.yolov5.models.common.BottleneckCSP[128, 128, 3]
#   3             -1  1    295424  yolov5.yolov5.models.common.Conv        [128, 256, 3, 2]
#   4             -1  1   1627904  yolov5.yolov5.models.common.BottleneckCSP[256, 256, 9]
#   5             -1  1   1180672  yolov5.yolov5.models.common.Conv        [256, 512, 3, 2]
#   6             -1  1   6499840  yolov5.yolov5.models.common.BottleneckCSP[512, 512, 9]
#   7             -1  1   4720640  yolov5.yolov5.models.common.Conv        [512, 1024, 3, 2]
#   8             -1  1   2624512  yolov5.yolov5.models.common.SPP         [1024, 1024, [5, 9, 13]]
#   9             -1  1  10234880  yolov5.yolov5.models.common.BottleneckCSP[1024, 1024, 3, False]
#  10             -1  1    525312  yolov5.yolov5.models.common.Conv        [1024, 512, 1, 1]
#  11             -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12        [-1, 6]  1         0  yolov5.yolov5.models.common.Concat      [1]
#  13             -1  1   2823680  yolov5.yolov5.models.common.BottleneckCSP[1024, 512, 3, False]
#  14             -1  1    131584  yolov5.yolov5.models.common.Conv        [512, 256, 1, 1]
#  15             -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16        [-1, 4]  1         0  yolov5.yolov5.models.common.Concat      [1]
#  17             -1  1    707328  yolov5.yolov5.models.common.BottleneckCSP[512, 256, 3, False]
#  18             -1  1      5397  torch.nn.modules.conv.Conv2d            [256, 21, 1, 1]
#  19             -2  1    590336  yolov5.yolov5.models.common.Conv        [256, 256, 3, 2]
#  20       [-1, 14]  1         0  yolov5.yolov5.models.common.Concat      [1]
#  21             -1  1   2561536  yolov5.yolov5.models.common.BottleneckCSP[512, 512, 3, False]
#  22             -1  1     10773  torch.nn.modules.conv.Conv2d            [512, 21, 1, 1]
#  23             -2  1   2360320  yolov5.yolov5.models.common.Conv        [512, 512, 3, 2]
#  24       [-1, 10]  1         0  yolov5.yolov5.models.common.Concat      [1]
#  25             -1  1  10234880  yolov5.yolov5.models.common.BottleneckCSP[1024, 1024, 3, False]
#  26             -1  1     21525  torch.nn.modules.conv.Conv2d            [1024, 21, 1, 1]
#  27   [-1, 22, 18]  1         0  yolov5.yolov5.models.yolo.Detect        [2, [[116, 90, 156, 198, 373, 326], [30, 61, 62, 45, 59, 119], [10, 13, 16, 30, 33, 23]]]
# Model Summary: 335 layers, 4.73987e+07 parameters, 4.73987e+07 gradients

# %%
out = M(torch.rand(1,3,512,512))

# %%
M.model
# Out:
# Sequential(
#   (0): Focus(
#     (conv): Conv(
#       (conv): Conv2d(12, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#   )
#   (1): Conv(
#     (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#   )
#   (2): BottleneckCSP(
#     (cv1): Conv(
#       (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (cv2): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (cv3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (cv4): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     (m): Sequential(
#       (0): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (1): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (2): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#   )
#   (3): Conv(
#     (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#   )
#   (4): BottleneckCSP(
#     (cv1): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (cv2): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (cv3): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (cv4): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     (m): Sequential(
#       (0): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (1): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (2): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (3): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (4): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (5): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (6): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (7): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (8): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#   )
#   (5): Conv(
#     (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#   )
#   (6): BottleneckCSP(
#     (cv1): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (cv2): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (cv3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (cv4): Conv(
#       (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     (m): Sequential(
#       (0): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (1): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (2): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (3): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (4): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (5): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (6): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (7): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (8): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#   )
#   (7): Conv(
#     (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(1024, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#   )
#   (8): SPP(
#     (cv1): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (cv2): Conv(
#       (conv): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(1024, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (m): ModuleList(
#       (0): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       (1): MaxPool2d(kernel_size=9, stride=1, padding=4, dilation=1, ceil_mode=False)
#       (2): MaxPool2d(kernel_size=13, stride=1, padding=6, dilation=1, ceil_mode=False)
#     )
#   )
#   (9): BottleneckCSP(
#     (cv1): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (cv2): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (cv3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (cv4): Conv(
#       (conv): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(1024, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (bn): BatchNorm2d(1024, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     (m): Sequential(
#       (0): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (1): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (2): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#   )
#   (10): Conv(
#     (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#   )
#   (11): Upsample(scale_factor=2.0, mode=nearest)
#   (12): Concat()
#   (13): BottleneckCSP(
#     (cv1): Conv(
#       (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (cv2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (cv3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (cv4): Conv(
#       (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     (m): Sequential(
#       (0): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (1): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (2): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#   )
#   (14): Conv(
#     (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#   )
#   (15): Upsample(scale_factor=2.0, mode=nearest)
#   (16): Concat()
#   (17): BottleneckCSP(
#     (cv1): Conv(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (cv2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (cv3): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (cv4): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     (m): Sequential(
#       (0): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (1): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (2): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#   )
#   (18): Conv2d(256, 21, kernel_size=(1, 1), stride=(1, 1))
#   (19): Conv(
#     (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#   )
#   (20): Concat()
#   (21): BottleneckCSP(
#     (cv1): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (cv2): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (cv3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (cv4): Conv(
#       (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     (m): Sequential(
#       (0): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (1): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (2): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#   )
#   (22): Conv2d(512, 21, kernel_size=(1, 1), stride=(1, 1))
#   (23): Conv(
#     (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#   )
#   (24): Concat()
#   (25): BottleneckCSP(
#     (cv1): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (cv2): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (cv3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (cv4): Conv(
#       (conv): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(1024, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (bn): BatchNorm2d(1024, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     (m): Sequential(
#       (0): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (1): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (2): Bottleneck(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#   )
#   (26): Conv2d(1024, 21, kernel_size=(1, 1), stride=(1, 1))
#   (27): Detect()
# )

# %%
for k,v in M.model.item():
    print(k)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-8f9308cae90b> in <module>
# ----> 1 for k,v in M.model.item():
#       2     print(k)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __getattr__(self, name)
#     592                 return modules[name]
#     593         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 594             type(self).__name__, name))
#     595
#     596     def __setattr__(self, name, value):
#
# AttributeError: 'Sequential' object has no attribute 'item'

# %%
len(out), out[0].shape, out[1].shape, out[2].shape
# Out:
# (3,
#  torch.Size([1, 3, 16, 16, 6]),
#  torch.Size([1, 3, 32, 32, 6]),
#  torch.Size([1, 3, 64, 64, 6]))

# %%
len(out), out[0].shape, out[1].shape, out[2].shape
# Out:
# (3,
#  torch.Size([1, 3, 16, 16, 7]),
#  torch.Size([1, 3, 32, 32, 7]),
#  torch.Size([1, 3, 64, 64, 7]))
